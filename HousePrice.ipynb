# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("HousePrices.csv")
df
# Out:
#        Id  Dwell_Type Zone_Class  ...  SaleType  SaleCondition Property_Sale_Price
# 0       1          60         RL  ...        WD         Normal              208500
# 1       2          20         RL  ...        WD         Normal              181500
# 2       3          60         RL  ...        WD         Normal              223500
# 3       4          70         RL  ...        WD        Abnorml              140000
# 4       5          60         RL  ...        WD         Normal              250000
# ...   ...         ...        ...  ...       ...            ...                 ...
# 2068  942          60         RL  ...        WD         Normal              214000
# 2069  943          90         RL  ...       Oth        Abnorml              150000
# 2070  944          90         RL  ...        WD         Normal              143000
# 2071  945          20         RL  ...       COD        Abnorml              137500
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2073 entries, 0 to 2072
# Data columns (total 81 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2073 non-null   int64
#  1   Dwell_Type           2073 non-null   int64
#  2   Zone_Class           2073 non-null   object
#  3   LotFrontage          1753 non-null   float64
#  4   LotArea              2073 non-null   int64
#  5   Road_Type            2073 non-null   object
#  6   Alley                129 non-null    object
#  7   Property_Shape       2073 non-null   object
#  8   LandContour          2073 non-null   object
#  9   Utilities            2073 non-null   object
#  10  LotConfig            2073 non-null   object
#  11  LandSlope            2073 non-null   object
#  12  Neighborhood         2073 non-null   object
#  13  Condition1           2073 non-null   object
#  14  Condition2           2073 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Id                       0
# Dwell_Type               0
# Zone_Class               0
# LotFrontage            320
# LotArea                  0
#                       ...
# MoSold                   0
# YrSold                   0
# SaleType                 0
# SaleCondition            0
# Property_Sale_Price      0
# Length: 81, dtype: int64

# %%
df.columns
# Out:
# Index(['Id', 'Dwell_Type', 'Zone_Class', 'LotFrontage', 'LotArea', 'Road_Type',
#        'Alley', 'Property_Shape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'Dwelling_Type', 'HouseStyle', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond',
#        'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#        'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF',
#        '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath',
#        'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
# ...

# %%
#Encoding - To convert any alphabte data into numbers
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df['Road_Type'] = le.fit_transform(df['Road_Type'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2073 entries, 0 to 2072
# Data columns (total 81 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2073 non-null   int64
#  1   Dwell_Type           2073 non-null   int64
#  2   Zone_Class           2073 non-null   object
#  3   LotFrontage          1753 non-null   float64
#  4   LotArea              2073 non-null   int64
#  5   Road_Type            2073 non-null   int64
#  6   Alley                129 non-null    object
#  7   Property_Shape       2073 non-null   object
#  8   LandContour          2073 non-null   object
#  9   Utilities            2073 non-null   object
#  10  LotConfig            2073 non-null   object
#  11  LandSlope            2073 non-null   object
#  12  Neighborhood         2073 non-null   object
#  13  Condition1           2073 non-null   object
#  14  Condition2           2073 non-null   object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2073 entries, 0 to 2072
# Data columns (total 81 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2073 non-null   int64
#  1   Dwell_Type           2073 non-null   int64
#  2   Zone_Class           2073 non-null   object
#  3   LotFrontage          1753 non-null   float64
#  4   LotArea              2073 non-null   int64
#  5   Road_Type            2073 non-null   int64
#  6   Alley                129 non-null    object
#  7   Property_Shape       2073 non-null   object
#  8   LandContour          2073 non-null   object
#  9   Utilities            2073 non-null   object
#  10  LotConfig            2073 non-null   object
#  11  LandSlope            2073 non-null   object
#  12  Neighborhood         2073 non-null   object
#  13  Condition1           2073 non-null   object
#  14  Condition2           2073 non-null   object
# ...

# %%
df['Zone_Class'] = le.fit_transform(df['Zone_Class'])
df['Property_Shape'] = le.fit_transform(df['Property_Shape'])
df['LandContour'] = le.fit_transform(df['LandContour'])
df['Utilities'] = le.fit_transform(df['Utilities'])
df['RoofStyle'] = le.fit_transform(df['RoofStyle'])
df['LotConfig'] = le.fit_transform(df['LotConfig'])
df['LandSlope'] = le.fit_transform(df['LandSlope'])
df['Neighborhood'] = le.fit_transform(df['Neighborhood'])
df['Condition1'] = le.fit_transform(df['Condition1'])
df['Condition2'] = le.fit_transform(df['Condition2'])
df['Dwelling_Type'] = le.fit_transform(df['Dwelling_Type'])
df['HouseStyle'] = le.fit_transform(df['HouseStyle'])
df['RoofMatl'] = le.fit_transform(df['RoofMatl'])
df['Exterior1st'] = le.fit_transform(df['Exterior1st'])
df['Exterior2nd'] = le.fit_transform(df['Exterior2nd'])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2073 entries, 0 to 2072
# Data columns (total 81 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2073 non-null   int64
#  1   Dwell_Type           2073 non-null   int64
#  2   Zone_Class           2073 non-null   int64
#  3   LotFrontage          1753 non-null   float64
#  4   LotArea              2073 non-null   int64
#  5   Road_Type            2073 non-null   int64
#  6   Alley                129 non-null    object
#  7   Property_Shape       2073 non-null   int64
#  8   LandContour          2073 non-null   int64
#  9   Utilities            2073 non-null   int64
#  10  LotConfig            2073 non-null   int64
#  11  LandSlope            2073 non-null   int64
#  12  Neighborhood         2073 non-null   int64
#  13  Condition1           2073 non-null   int64
#  14  Condition2           2073 non-null   int64
# ...

# %%
df['MasVnrType'] = df['MasVnrType'].replace("None", np.nan)
df['MasVnrType'] = df['MasVnrType'].fillna("np.mean")
df['MasVnrType'] = le.fit_transform(df['MasVnrType'])
print(df['MasVnrType'])

df['ExterQual'] = le.fit_transform(df['ExterQual'])
df['ExterCond'] = le.fit_transform(df['ExterCond'])
df['ExterCond'] = le.fit_transform(df['ExterCond'])
df['Foundation'] = le.fit_transform(df['Foundation'])
#df.info()
# Out:
# 0       1
# 1       3
# 2       1
# 3       3
# 4       1
#        ..
# 2068    1
# 2069    3
# 2070    3
# 2071    1
# 2072    3
# Name: MasVnrType, Length: 2073, dtype: int64

# %%
df['BsmtQual'] = df['BsmtQual'].replace("None", np.nan)
df['BsmtQual'] = df['BsmtQual'].fillna("0")
df['BsmtQual'] = le.fit_transform(df['BsmtQual'])

df['BsmtCond'] = df['BsmtCond'].replace("None", np.nan)
df['BsmtCond'] = df['BsmtCond'].fillna("0")
df['BsmtCond'] = le.fit_transform(df['BsmtCond'])

df['BsmtExposure'] = df['BsmtExposure'].replace("None", np.nan)
df['BsmtExposure'] = df['BsmtExposure'].fillna("0")
df['BsmtExposure'] = le.fit_transform(df['BsmtExposure'])

df['BsmtFinType1'] = df['BsmtFinType1'].replace("None", np.nan)
df['BsmtFinType1'] = df['BsmtFinType1'].fillna("0")
df['BsmtFinType1'] = le.fit_transform(df['BsmtFinType1'])

df['BsmtFinType2'] = df['BsmtFinType2'].replace("None", np.nan)
df['BsmtFinType2'] = df['BsmtFinType2'].fillna("0")
df['BsmtFinType2'] = le.fit_transform(df['BsmtFinType2'])

df['Heating'] = le.fit_transform(df['Heating'])
df['HeatingQC'] = le.fit_transform(df['HeatingQC'])
df['CentralAir'] = le.fit_transform(df['CentralAir'])

df['Electrical'] = df['Electrical'].replace("None", np.nan)
df['Electrical'] = df['Electrical'].fillna("0")
df['Electrical'] = le.fit_transform(df['Electrical'])

df['KitchenQual'] = le.fit_transform(df['KitchenQual'])
df['Functional'] = le.fit_transform(df['Functional'])
df['PavedDrive'] = le.fit_transform(df['PavedDrive'])
df['SaleType'] = le.fit_transform(df['SaleType'])
df['SaleCondition'] = le.fit_transform(df['SaleCondition'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2073 entries, 0 to 2072
# Data columns (total 81 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2073 non-null   int64
#  1   Dwell_Type           2073 non-null   int64
#  2   Zone_Class           2073 non-null   int64
#  3   LotFrontage          1753 non-null   float64
#  4   LotArea              2073 non-null   int64
#  5   Road_Type            2073 non-null   int64
#  6   Alley                129 non-null    object
#  7   Property_Shape       2073 non-null   int64
#  8   LandContour          2073 non-null   int64
#  9   Utilities            2073 non-null   int64
#  10  LotConfig            2073 non-null   int64
#  11  LandSlope            2073 non-null   int64
#  12  Neighborhood         2073 non-null   int64
#  13  Condition1           2073 non-null   int64
#  14  Condition2           2073 non-null   int64
# ...

# %%
df['FireplaceQu'] = df['FireplaceQu'].replace("None", np.nan)
df['FireplaceQu'] = df['FireplaceQu'].fillna("0")
df['FireplaceQu'] = le.fit_transform(df['FireplaceQu'])

df['FireplaceQu'] = df['FireplaceQu'].replace("None", np.nan)
df['FireplaceQu'] = df['FireplaceQu'].fillna("0")
df['FireplaceQu'] = le.fit_transform(df['FireplaceQu'])

df['GarageType'] = df['GarageType'].replace("None", np.nan)
df['GarageType'] = df['GarageType'].fillna("0")
df['GarageType'] = le.fit_transform(df['GarageType'])

df['GarageFinish'] = df['GarageFinish'].replace("None", np.nan)
df['GarageFinish'] = df['GarageFinish'].fillna("0")
df['GarageFinish'] = le.fit_transform(df['GarageFinish'])

df['GarageQual'] = df['GarageQual'].replace("None", np.nan)
df['GarageQual'] = df['GarageQual'].fillna("0")
df['GarageQual'] = le.fit_transform(df['GarageQual'])

df['GarageCond'] = df['GarageCond'].replace("None", np.nan)
df['GarageCond'] = df['GarageCond'].fillna("0")
df['GarageCond'] = le.fit_transform(df['GarageCond'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2073 entries, 0 to 2072
# Data columns (total 81 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2073 non-null   int64
#  1   Dwell_Type           2073 non-null   int64
#  2   Zone_Class           2073 non-null   int64
#  3   LotFrontage          1753 non-null   float64
#  4   LotArea              2073 non-null   int64
#  5   Road_Type            2073 non-null   int64
#  6   Alley                129 non-null    object
#  7   Property_Shape       2073 non-null   int64
#  8   LandContour          2073 non-null   int64
#  9   Utilities            2073 non-null   int64
#  10  LotConfig            2073 non-null   int64
#  11  LandSlope            2073 non-null   int64
#  12  Neighborhood         2073 non-null   int64
#  13  Condition1           2073 non-null   int64
#  14  Condition2           2073 non-null   int64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2073 entries, 0 to 2072
# Data columns (total 81 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2073 non-null   int64
#  1   Dwell_Type           2073 non-null   int64
#  2   Zone_Class           2073 non-null   int64
#  3   LotFrontage          1753 non-null   float64
#  4   LotArea              2073 non-null   int64
#  5   Road_Type            2073 non-null   int64
#  6   Alley                129 non-null    object
#  7   Property_Shape       2073 non-null   int64
#  8   LandContour          2073 non-null   int64
#  9   Utilities            2073 non-null   int64
#  10  LotConfig            2073 non-null   int64
#  11  LandSlope            2073 non-null   int64
#  12  Neighborhood         2073 non-null   int64
#  13  Condition1           2073 non-null   int64
#  14  Condition2           2073 non-null   int64
# ...

# %%
del df['Alley']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2073 entries, 0 to 2072
# Data columns (total 80 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2073 non-null   int64
#  1   Dwell_Type           2073 non-null   int64
#  2   Zone_Class           2073 non-null   int64
#  3   LotFrontage          1753 non-null   float64
#  4   LotArea              2073 non-null   int64
#  5   Road_Type            2073 non-null   int64
#  6   Property_Shape       2073 non-null   int64
#  7   LandContour          2073 non-null   int64
#  8   Utilities            2073 non-null   int64
#  9   LotConfig            2073 non-null   int64
#  10  LandSlope            2073 non-null   int64
#  11  Neighborhood         2073 non-null   int64
#  12  Condition1           2073 non-null   int64
#  13  Condition2           2073 non-null   int64
#  14  Dwelling_Type        2073 non-null   int64
# ...

# %%
df['GarageYrBlt'] = df['GarageYrBlt'].replace("None", np.nan)
df['GarageYrBlt'] = df['GarageYrBlt'].fillna(0)
df['GarageYrBlt'] = pd.to_numeric(df['GarageYrBlt'])

df['LotFrontage'] = df['LotFrontage'].replace("None", np.nan)
df['LotFrontage'] = df['LotFrontage'].fillna(0)
df['LotFrontage'] = pd.to_numeric(df['LotFrontage'])

df['MasVnrArea'] = df['MasVnrArea'].replace("None", np.nan)
df['MasVnrArea'] = df['MasVnrArea'].fillna(0)
df['MasVnrArea'] = pd.to_numeric(df['MasVnrArea'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2073 entries, 0 to 2072
# Data columns (total 80 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2073 non-null   int64
#  1   Dwell_Type           2073 non-null   int64
#  2   Zone_Class           2073 non-null   int64
#  3   LotFrontage          2073 non-null   float64
#  4   LotArea              2073 non-null   int64
#  5   Road_Type            2073 non-null   int64
#  6   Property_Shape       2073 non-null   int64
#  7   LandContour          2073 non-null   int64
#  8   Utilities            2073 non-null   int64
#  9   LotConfig            2073 non-null   int64
#  10  LandSlope            2073 non-null   int64
#  11  Neighborhood         2073 non-null   int64
#  12  Condition1           2073 non-null   int64
#  13  Condition2           2073 non-null   int64
#  14  Dwelling_Type        2073 non-null   int64
# ...

# %%
del df['PoolQC']
del df['Fence']
del df['MiscFeature']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2073 entries, 0 to 2072
# Data columns (total 77 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2073 non-null   int64
#  1   Dwell_Type           2073 non-null   int64
#  2   Zone_Class           2073 non-null   int64
#  3   LotFrontage          2073 non-null   float64
#  4   LotArea              2073 non-null   int64
#  5   Road_Type            2073 non-null   int64
#  6   Property_Shape       2073 non-null   int64
#  7   LandContour          2073 non-null   int64
#  8   Utilities            2073 non-null   int64
#  9   LotConfig            2073 non-null   int64
#  10  LandSlope            2073 non-null   int64
#  11  Neighborhood         2073 non-null   int64
#  12  Condition1           2073 non-null   int64
#  13  Condition2           2073 non-null   int64
#  14  Dwelling_Type        2073 non-null   int64
# ...

# %%
df.corr()
# Out:
#                            Id  Dwell_Type  ...  SaleCondition  Property_Sale_Price
# Id                   1.000000    0.043264  ...      -0.011822            -0.002491
# Dwell_Type           0.043264    1.000000  ...       0.005838            -0.017399
# Zone_Class           0.008184    0.002442  ...      -0.007771            -0.168772
# LotFrontage          0.106168   -0.042185  ...       0.052878             0.185680
# LotArea              0.004201   -0.033609  ...       0.032000             0.211572
# ...                       ...         ...  ...            ...                  ...
# MoSold               0.000234   -0.020589  ...       0.016769             0.041053
# YrSold               0.043219    0.018891  ...      -0.005215             0.001740
# SaleType             0.001829    0.011964  ...       0.219340            -0.060839
# SaleCondition       -0.011822    0.005838  ...       1.000000             0.214792
# ...

# %%
#Check for VIF,
#If VIF <5, No Multi, VIF: 5-10, Presence of Multi but u can use those columns
#IF VIF >10, Confirm presence of Multi, We need to remove it.
import numpy as np
X = np.array(df)
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif = [variance_inflation_factor(X, i) for i in range(X.shape[1])]
print(vif)
X = pd.DataFrame(X)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/stats/outliers_influence.py:185: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# ...

# %%
sns.scatterplot(x = 'Dwell_Type', y = 'Zone_Class', data = df)

# %%
X = df.iloc[:,:-1]
print(X)
# Out:
#        Id  Dwell_Type  Zone_Class  ...  YrSold  SaleType  SaleCondition
# 0       1          60           3  ...    2008         8              4
# 1       2          20           3  ...    2007         8              4
# 2       3          60           3  ...    2008         8              4
# 3       4          70           3  ...    2006         8              0
# 4       5          60           3  ...    2008         8              4
# ...   ...         ...         ...  ...     ...       ...            ...
# 2068  942          60           3  ...    2009         8              4
# 2069  943          90           3  ...    2007         7              0
# 2070  944          90           3  ...    2007         8              4
# 2071  945          20           3  ...    2009         0              0
# 2072  946          50           4  ...    2009         8              4
#
# [2073 rows x 76 columns]

# %%
y = df.iloc[:,-1:]
print(y)
# Out:
#       Property_Sale_Price
# 0                  208500
# 1                  181500
# 2                  223500
# 3                  140000
# 4                  250000
# ...                   ...
# 2068               214000
# 2069               150000
# 2070               143000
# 2071               137500
# 2072               124900
#
# [2073 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y, test_size = 0.2, random_state = 123)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (1658, 76)
# (1658, 1)
# (415, 76)
# (415, 1)

# %%
from sklearn import linear_model #Parametric Model

# %%
reg = linear_model.LinearRegression()

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
X_test.head()
# Out:
#         Id  Dwell_Type  Zone_Class  ...  YrSold  SaleType  SaleCondition
# 1935   981          85           3  ...    2008         8              4
# 715    716          20           3  ...    2009         8              4
# 1392  1393          85           3  ...    2006         8              4
# 452    453          60           3  ...    2007         8              4
# 1270  1271          40           3  ...    2010         8              4
#
# [5 rows x 76 columns]

# %%
y_test.head()
# Out:
#       Property_Sale_Price
# 1935               178400
# 715                165000
# 1392               123000
# 452                204000
# 1270               260000

# %%
#Testing
y_pred = reg.predict(X_test)

# %%
y_pred
# Out:
# array([[222233.18633685],
#        [163142.19542457],
#        [125221.9997752 ],
#        [230131.90234862],
#        [275254.55600783],
#        [117283.76488701],
#        [245968.04745724],
#        [233021.99181776],
#        [103968.85378371],
#        [264324.21062229],
#        [238395.32403582],
#        [281142.83542754],
#        [169310.07784067],
#        [128898.12056963],
#        [199394.99041485],
#        [247860.58091969],
#        [350285.14188545],
#        [152302.3270349 ],
#        [216183.30040556],
#        [165897.79900982],
#        [136810.70386967],
#        [223147.60804056],
#        [281525.47464042],
#        [251776.78100295],
#        [259293.8611975 ],
#        [223275.53620726],
#        [181464.357939  ],
#        [103689.93842017],
#        [289813.40621765],
#        [108480.52779536],
#        [102298.67032405],
#        [192493.75742718],
#        [113226.31974878],
#        [111000.19498592],
#        [108388.41453616],
# ...

# %%
#Mean Error Value
#Mean Squared Error 
#Evaluation
from sklearn.metrics import mean_squared_error, r2_score
print(mean_squared_error(y_test, y_pred)) #MSE
# Out:
# 951062368.6590695

# %%
import matplotlib.pyplot as plt
# Plot outputs
plt.scatter(y_test, y_pred,  color='black')

# %%
print(r2_score(y_test, y_pred)) #Coefficient of Determination
# Out:
# 0.8698909862307944

# %%
#Training Accuracy
y_pred = reg.predict(X_train)

# %%
print(r2_score(y_train, y_pred)) #Coefficient of Determination
# Out:
# 0.8418011898634525

# %%
y_test.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe02a565550>]],
#       dtype=object)

# %%
y_train.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe029dffe48>]],
#       dtype=object)
